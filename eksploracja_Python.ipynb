# %%
import pandas as pd
import json
import seaborn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("all.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 kadencja   etap            lista  \
# 0           1        I  start      Adam Halber
# 1           2        I    end      Adam Halber
# 2           3        I  start  Adam Matuszczak
# 3           4        I    end  Adam Matuszczak
# 4           5        I  start  Adam Piechowicz
#
#                                                 klub
# 0    Sojusz Lewicy Demokratycznej Klub Parlamentarny
# 1                      Polska Partia Przyjaciół Piwa
# 2                Klub Parlamentarny Konwencja Polska
# 3                           Wyborcza Akcja Katolicka
# 4  Koło Poselskie Partii Emerytów i Rencistów "Na...

# %%
len(df.klub.unique())
# Out:
# 89

# %%
def clean_name(klub):
    return klub.replace("Koło", "").replace("Klub", "").replace("Parlamentarne", "").replace("Parlamentarny", "").replace("Poselskie", "").strip()

# %%
df.klub = df.klub.apply(clean_name)

# %%
len(df.klub.value_counts())
# Out:
# 76

# %%
df.klub.value_counts().plot(kind='barh', figsize=(6,12))

# %%
for kadencja in ["I", "II", "III", "IV", "V", "VI", "VII"]:
    for etap in ["start", "end"]:
        df[(df.kadencja == kadencja) & (df.etap == etap)].klub.value_counts().plot(kind='barh', figsize=(6,12))
        plt.title(kadencja + " " + etap)
        plt.show()
